# %% [markdown]
# <a href="https://colab.research.google.com/github/kalludevakeerthana/Innomatics-/blob/main/Logic_Building_Task___1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username="admin"
password="1234"
if username=="admin" and password=="1234":
    print("login successfull")
else:
    print("invalid credentials")
# Out:
# login successfull

# %%
marks = [45, 78, 90, 33, 60]
for result in marks:
  if result >= 50:
    print("pass")
  else:
    print("fail")
print(f"Total Students: {len(marks)}")
passed_students = 0
for result in marks:
  if result >= 50:
    passed_students += 1
    print("pass")
print(f"Passed Students: {passed_students}")
failed_students = len(marks) - passed_students
print(f"Failed Students: {failed_students}")
total_students = len(marks)
print(f"Total Students: {total_students}")
# Out:
# fail
# pass
# pass
# fail
# pass
# Total Students: 5
# pass
# pass
# pass
# Passed Students: 3
# Failed Students: 2
# Total Students: 5

# %%
names = [" Alice ", "bob", " CHARLIE "]
names=[item.lower() for item in names]
print(names)
cleaned_list=names.copy()
for item in names:
    cleaned_list.remove(item)
print(cleaned_list)
# Out:
# [' alice ', 'bob', ' charlie ']
# []

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
  print(len(msg))
  if len(msg)>10:
    print("flag,msg has more than 10 characters")
# Out:
# 2
# 23
# flag,msg has more than 10 characters
# 2

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error=logs.count("ERROR")
print(error)
# Out:
# 2
